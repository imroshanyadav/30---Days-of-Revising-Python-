# %%
a =int(input("enter the num"))
if(a>4):
    print("hello world")
else:
    print('noob')
# Out:
# noob

# %%
a = int(input("Enter the number:"))
if a > 0:
    print('A is a positive number')
elif a < 0:
    print('A is a negative number')
else:
    print('A is zero')
# Out:
# A is a positive number

# %%
a = int(input("Enter the numer"))
print("You are adult") if (a>18) else print("you are a boy")
# Out:
# You are adult

# %%
a = 0
if a > 0:
    if a % 2 == 0:
        print('A is a positive and even integer')
    else:
        print('A is a positive number')
elif a == 0:
    print('A is zero')
else:
    print('A is a negative number')
# Out:
# A is zero

# %%
a = 24
if a > 0:
    if a % 2 == 0:
        print('A is a positive and even integer')
    else:
        print('A is a positive number')
elif a == 0:
    print('A is zero')
else:
    print('A is a negative number')
# Out:
# A is a positive and even integer

# %%
a = 67
if a > 0 and a % 2 == 0:
        print('A is an even and positive integer')
elif a > 0 and a % 2 !=  0:
     print('A is a positive and Odd')
elif a == 0:
    print('A is zero')
else:
    print('A is negative')
# Out:
# A is a positive and Odd
