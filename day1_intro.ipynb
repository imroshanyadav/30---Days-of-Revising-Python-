# %% [markdown]
# Intro to some basic syntax

# %%
print("hello")
# Out:
# hello

# %%
print(2+4)
print(3-4)
print(4*5)
print(3/8)
print (3**4)
print(3%2)
print(3//2) #floor division operator
# Out:
# 6
# -1
# 20
# 0.375
# 81
# 1
# 1

# %% [markdown]
# ## check the datatype of the variable

# %%
print(type(4))
print(type(3.12))
print(type(2+3j))
print(type("roshan yadav"))
print(type({'name': "Roshan Yadav"}))
print(type({3,2,2,3,4,5}))
print(type([3,4,5,5]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'dict'>
# <class 'set'>
# <class 'list'>

# %%
# Variables in Python
first_name = 'Asabeneh'
last_name = 'Yetayeh'
country = 'Finland'
city = 'Helsinki'
age = 250
is_married = True
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
   'firstname':'Asabeneh',
   'lastname':'Yetayeh',
   'country':'Finland',
   'city':'Helsinki'
   }

# Printing the value stored in a variable

print(first_name)
print(last_name)
print(skills)
print(person_info)
# Out:
# Asabeneh
# Yetayeh
# ['HTML', 'CSS', 'JS', 'React', 'Python']
# {'firstname': 'Asabeneh', 'lastname': 'Yetayeh', 'country': 'Finland', 'city': 'Helsinki'}

# %%
# Taking input in python

name = input("enter the full name of yours:")
print(name)
age = int(input("enter your age :"))
print(age)
# Out:
# Roshan Yadav
# 21
